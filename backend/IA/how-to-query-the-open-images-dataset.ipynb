# %% [markdown]
# **How to Query the Open Images Dataset (BigQuery)**

# %%
import bq_helper
from bq_helper import BigQueryHelper
# https://www.kaggle.com/sohier/introduction-to-the-bq-helper-package
open_images = bq_helper.BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="open_images")

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "open_images")
bq_assistant.list_tables()
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# <ipython-input-2-73079591cfc7> in <module>()
#       1 bq_assistant = BigQueryHelper("bigquery-public-data", "open_images")
# ----> 2 bq_assistant.list_tables()
#
# /src/bq-helper/bq_helper.py in list_tables(self)
#     113         List the names of the tables in a dataset
#     114         """
# --> 115         self.__fetch_dataset()
#     116         return([x.table_id for x in self.client.list_tables(self.dataset)])
#     117
#
# /src/bq-helper/bq_helper.py in __fetch_dataset(self)
#      38         """
#      39         if self.dataset is None:
# ---> 40             self.dataset = self.client.get_dataset(self.__dataset_ref)
#      41
#      42     def __fetch_table(self, table_name):
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/bigquery/client.py in get_dataset(self, dataset_ref, retry)
#     346         api_response = self._call_api(retry,
#     347                                       method='GET',
# --> 348                                       path=dataset_ref.path)
#     349         return Dataset.from_api_repr(api_response)
#     350
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/bigquery/client.py in _call_api(self, retry, **kwargs)
#     329         if retry:
#     330             call = retry(call)
# --> 331         return call()
#     332
#     333     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY):
#
# /opt/conda/lib/python3.6/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     258                 sleep_generator,
#     259                 self._deadline,
# --> 260                 on_error=on_error,
#     261             )
#     262
#
# /opt/conda/lib/python3.6/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     175     for sleep in sleep_generator:
#     176         try:
# --> 177             return target()
#     178
#     179         # pylint: disable=broad-except
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     291
#     292         if not 200 <= response.status_code < 300:
# --> 293             raise exceptions.from_http_response(response)
#     294
#     295         if expect_json and response.content:
#
# InternalServerError: 500 GET https://dp.kaggle.net/bigquery/v2/projects/bigquery-public-data/datasets/open_images: Unable to cast object of type 'System.DBNull' to type 'System.Int64'.

# %%
bq_assistant.head("images", num_rows=3)

# %%
bq_assistant.table_schema("images")

# %% [markdown]
# Which labels are in the dataset?

# %%
query1 = """SELECT
  *
FROM
  `bigquery-public-data.open_images.dict`
LIMIT
  10;
        """
response1 = open_images.query_to_pandas_safe(query1)
response1.head(10)

# %% [markdown]
# Which labels have "bus" in their display names?

# %%
query2 = """SELECT
  *
FROM
  `bigquery-public-data.open_images.dict`
WHERE
  label_display_name LIKE '%bus%'
LIMIT
  20;
        """
response2 = open_images.query_to_pandas_safe(query2)
response2.head(10)

# %% [markdown]
# How many images of a trolleybus are in the dataset?

# %%
query3 = """SELECT
  COUNT(*)
FROM
  `bigquery-public-data.open_images.labels` a
INNER JOIN
  `bigquery-public-data.open_images.images` b
ON
  a.image_id = b.image_id
WHERE
  a.label_name='/m/0f6pl'
  AND a.confidence > 0.5;
        """
response3 = open_images.query_to_pandas_safe(query3, max_gb_scanned=10)
response3.head(10)

# %% [markdown]
# What are some landing pages of images with a trolleybus?

# %%
query4 = """SELECT
  original_landing_url,
  confidence
FROM
  `bigquery-public-data.open_images.labels` l
INNER JOIN
  `bigquery-public-data.open_images.images` i
ON
  l.image_id = i.image_id
WHERE
  label_name='/m/0f6pl'
  AND confidence = 1
  AND subset='validation'
LIMIT
  10;
        """
response4 = open_images.query_to_pandas_safe(query4, max_gb_scanned=10)
response4.head(10)

# %%
query5 = """SELECT
  original_landing_url,
  confidence
FROM
  `bigquery-public-data.open_images.labels` l
INNER JOIN
  `bigquery-public-data.open_images.images` i
ON
  l.image_id = i.image_id
WHERE
  label_name='/m/0f6pl'
  AND confidence = 1
  AND subset='validation'
LIMIT
  10;
        """
response5 = open_images.query_to_pandas_safe(query5, max_gb_scanned=10)
response5.head(10)

# %% [markdown]
# Which images with cherries are in the training set?

# %%
query6 = """SELECT
  i.image_id AS image_id,
  original_url,
  confidence
FROM
  `bigquery-public-data.open_images.labels` l
INNER JOIN
  `bigquery-public-data.open_images.images` i
ON
  l.image_id = i.image_id
WHERE
  label_name='/m/0f8sw'
  AND confidence >= 0.85
  AND Subset='train'
LIMIT
  10;
        """
response6 = open_images.query_to_pandas_safe(query6, max_gb_scanned=10)
response6.head(10)

# %% [markdown]
# Credit: Many functions are adaptations from https://cloud.google.com/bigquery/public-data/openimages
